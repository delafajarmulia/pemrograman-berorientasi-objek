# %% [markdown]
# ## Praktikum 1 - Inheritance Dasar

# %%
# parent class
class Kendaraan:
    def __init__(self, merk):
        self.merk = merk

    def mulai_mesin(self):
        print(f'Mesin kendaraan {self.merk} dinyalakan.')

# child class
class Mobil(Kendaraan):
    def __init__(self, merk, warna):
        self.merk = merk
        self.warna = warna

    def info_mobil(self):
        print(f'Ini adalah mobil {self.merk} berwarna {self.warna}')

if __name__ == "__main__":
    mobil_tesla = Mobil("Tesla Model S", "Merah")
    mobil_tesla.info_mobil()
    mobil_tesla.mulai_mesin()

    print(f'Merk mobil: {mobil_tesla.merk}')
# Out:
# Ini adalah mobil Tesla Model S berwarna Merah
# Mesin kendaraan Tesla Model S dinyalakan.
# Merk mobil: Tesla Model S

# %% [markdown]
# ## Praktikum 2 - Menggunakan super() dalam konstruktor

# %%
# parent class
class Person:
    def __init__(self, nama, usia):
        print(f"Memanggil __init__ Person untuk '{nama}'")
        self.nama = nama
        self.usia = usia

    def perkenalkan_diri(self):
        print(f"Halo, nama saya {self.nama}, usia saya {self.usia} tahun.")

# child class
class Student(Person):
    def __init__(self, nama, usia, student_id, jurusan):
        print(f"(Memanggil __init__ Student untuk '{nama})")
        super().__init__(nama, usia)
        self.student_id = student_id
        self.jurusan = jurusan
        print(f"(Inisialisasi attribute Student selesai untuk '{nama})")

    def info_akademik(self):
        print(f"ID Mahasiswa: {self.student_id}")
        print(f"Jurusan: {self.jurusan}")

    # override perkenalkan_diri 
    def perkenalkan_diri(self):
        super().perkenalkan_diri() # panggil versi Person
        print(f"Saya adalah mahasiswa dengan ID {self.student_id}, jurusan {self.jurusan}")

if __name__ == "__main__":
    dosen = Person("Pak Anton", 45)
    print("-" * 20)
    dosen.perkenalkan_diri()
    print("\n" + "=" * 30 + "\n")

    mahasiswa = Student("Dewi", 20, "MHS001", "Teknik Komputer")
    print("-" * 20)
    mahasiswa.perkenalkan_diri()    # panggil versi override student
    print("\n" + "=" * 30 + "\n")
    mahasiswa.info_akademik()

    print(f"\nUsia mahasiswa {mahasiswa.nama}: {mahasiswa.usia}")
# Out:
# Memanggil __init__ Person untuk 'Pak Anton'
# --------------------
# Halo, nama saya Pak Anton, usia saya 45 tahun.
#
# ==============================
#
# (Memanggil __init__ Student untuk 'Dewi)
# Memanggil __init__ Person untuk 'Dewi'
# (Inisialisasi attribute Student selesai untuk 'Dewi)
# --------------------
# Halo, nama saya Dewi, usia saya 20 tahun.
# Saya adalah mahasiswa dengan ID MHS001, jurusan Teknik Komputer
#
# ==============================
#
# ID Mahasiswa: MHS001
# Jurusan: Teknik Komputer
#
# Usia mahasiswa Dewi: 20

# %% [markdown]
# ## Praktikum 3 - Method Overriding dan super()

# %%
# parent class
class Hewan:
    def __init__(self, nama):
        self.nama = nama

    def bersuara(self):
        print(f"{self.nama} mengeluarkan suara generik.")

    def tampilkan_info(self):
        print(f"Ini adalah hewan bernama {self.nama}")

# child class
class Kucing(Hewan):
    def __init__(self, nama, ras):
        super().__init__(nama)
        self.ras = ras

    def bersuara(self):
        print(f"{self.nama} (Kucing) mengeong: Meow!")

    def tampilkan_info(self):
        super().tampilkan_info()
        print(f"Ini adalah kucing ras {self.ras}")

if __name__ == "__main__":
    hewan_umum = Hewan("Mahluk")
    kucing_persia = Kucing("Puspus", "Persia")

    print("Info Hewan Umum:")
    hewan_umum.tampilkan_info()
    hewan_umum.bersuara()
    print("-" * 20)

    print("info kucing persia")
    kucing_persia.tampilkan_info()
    kucing_persia.bersuara()
# Out:
# Info Hewan Umum:
# Ini adalah hewan bernama Mahluk
# Mahluk mengeluarkan suara generik.
# --------------------
# info kucing persia
# Ini adalah hewan bernama Puspus
# Ini adalah kucing ras Persia
# Puspus (Kucing) mengeong: Meow!

# %% [markdown]
# ## Praktikum 4 - Multi-level Inheritance (Pewarisan Bertingkat)

# %%
# parent class - level 1
class Organisme:
    def __init__(self, nama):
        self.nama = nama
        print(f"Organisme '{self.nama}' diciptakan")

    def bernapas(self):
        print(f"{self.nama} sedang bernapas")

# child class level 1 (mewarisi dari organisme)
class Hewan(Organisme):
    def __init__(self, nama, jenis_makanan):
        super().__init__(nama)
        self.jenis_makanan = jenis_makanan
        print(f"Hewan '{self.nama}' adalah {self.jenis_makanan}")

    def bergerak(self):
        print(f"{self.nama} sedang bergerak")

# child class level 2 (mewarisi dari hewan)
class Mamalia(Hewan):
    def __init__(self, nama, jenis_makanan, jumlah_kaki):
        super().__init__(nama, jenis_makanan)
        self.jumlah_kaki = jumlah_kaki
        print(f"Mamalia '{self.nama}' memiliki {self.jumlah_kaki} kaki")

    def menyusui(self):
        print(f"{self.nama} sedang menyusui")

if __name__ == "__main__":
    kucing = Mamalia("Kucing persia", "Karnivora", 4)
    print("-" * 20)

    kucing.menyusui()
    kucing.bergerak()
    print(f"Jenis makanan: {kucing.jenis_makanan}")

    # dari organisme
    kucing.bernapas()
    print(f"Nama organisme: {kucing.nama}")
# Out:
# Organisme 'Kucing persia' diciptakan
# Hewan 'Kucing persia' adalah Karnivora
# Mamalia 'Kucing persia' memiliki 4 kaki
# --------------------
# Kucing persia sedang menyusui
# Kucing persia sedang bergerak
# Jenis makanan: Karnivora
# Kucing persia sedang bernapas
# Nama organisme: Kucing persia

# %% [markdown]
# ## Praktikum 5 - Hierarchical Inheritance

# %%
import locale

try:
    locale.setlocale(locale.LC_ALL, 'id_ID.UTF-8')
except locale.Error:
    print("Locale id-ID.UTF-8 tidak tersedia, menggunakan locale default")

# helper function
def format_rupiah(angka):
    return locale.currency(angka, grouping=True, symbol='Rp ')

# parent class 
class Pegawai:
    def __init__(self, nama, id_pegawai, gaji_pokok):
        self.nama = nama
        self.id_pegawai = id_pegawai
        self.gaji_pokok = gaji_pokok

    def hitung_gaji(self):
        return self.gaji_pokok

    def tampilkan_info(self):
        print(f"ID: {self.id_pegawai}, Nama: {self.nama}")
        print(f"Gaji pokok: {format_rupiah(self.gaji_pokok)}")

# child class 1
class Manager(Pegawai):
    def __init__(self, nama, id_pegawai, gaji_pokok, tunjangan_jabatan):
        super().__init__(nama, id_pegawai, gaji_pokok)
        self.tunjangan_jabatan = tunjangan_jabatan

    def hitung_gaji(self):
        gaji_total = super().hitung_gaji() + self.tunjangan_jabatan
        return gaji_total

    def tampilkan_info(self):
        print("--- Info Manager ---")
        super().tampilkan_info()
        print(f"Tunjanngan jabatan: {format_rupiah(self.tunjangan_jabatan)}")
        print(f"Total gaji: {format_rupiah(self.hitung_gaji())}")

# child class 2
class StafTeknis(Pegawai):
    def __init__(self, nama, id_pegawai, gaji_pokok, keahlian, bonus_keahlian):
        super().__init__(nama, id_pegawai, gaji_pokok)
        self.keahlian = keahlian
        self.bonus_keahlian = bonus_keahlian

    def hitung_gaji(self):
        gaji_total = super().hitung_gaji() + self.bonus_keahlian
        return gaji_total

    def tampilkan_info(self):
        print("--- Info Staf Teknis ---")
        super().tampilkan_info()
        print(f"Keahlian: {self.keahlian}")
        print(f"Bonus keahlian: {format_rupiah(self.bonus_keahlian)}")
        print(f"Total Gaji: {format_rupiah(self.hitung_gaji())}")

if __name__ == "__main__":
    manager1 = Manager("Budi Santoso", "M001", 10000000, 5000000)
    staf1 = StafTeknis("Citra Lestari", "S001", 7000000, "Python Programming", 1500000)
    pegawai_baru = Pegawai("Rian", "P005", 5000000) # Pegawai biasa

    print("Menampilkan Informasi Pegawai:")
    manager1.tampilkan_info()
    print("-" * 30)
    staf1.tampilkan_info()
    print("-" * 30)

    print("--- Info Pegawai Baru ---")
    pegawai_baru.tampilkan_info()
    print(f" Total Gaji: {format_rupiah(pegawai_baru.hitung_gaji())}")

    # Memanggil versi Pegawai
    print("-" * 30)
# Out:
# Menampilkan Informasi Pegawai:
# --- Info Manager ---
# ID: M001, Nama: Budi Santoso
# Gaji pokok: Rp10.000.000,00
# Tunjanngan jabatan: Rp5.000.000,00
# Total gaji: Rp15.000.000,00
# ------------------------------
# --- Info Staf Teknis ---
# ID: S001, Nama: Citra Lestari
# Gaji pokok: Rp7.000.000,00
# Keahlian: Python Programming
# Bonus keahlian: Rp1.500.000,00
# Total Gaji: Rp8.500.000,00
# ------------------------------
# --- Info Pegawai Baru ---
# ID: P005, Nama: Rian
# Gaji pokok: Rp5.000.000,00
#  Total Gaji: Rp5.000.000,00
# ------------------------------

# %% [markdown]
# ## Praktikum 6 - Memeriksa Tipe Instance dengan instance()

# %%
class BentukGeometri:
    def __init__(self, nama_bentuk):
        self.nama = nama_bentuk

    def tampilkan_nama(self):
        print(f"Ini adalah bentuk {self.nama}")

    def hitung_luas(self):
        print(f"Luas {self.nama} tidak bisa dihitunng (generik)")

class PersegiPanjang(BentukGeometri):
    def __init__(self, panjang, lebar):
        super().__init__("Persegi Panjang")
        self.panjang = panjang
        self.lebar = lebar

    def hitung_luas(self):
        luas = self.panjang * self.lebar
        print(f"Luas {self.nama}: {luas}")

class Segitiga(BentukGeometri):
    def __init__(self, alas, tinggi):
        super().__init__("Segitiga")
        self.alas = alas
        self.tinggi = tinggi

    def hitung_luas(self):
        luas = 0.5 * self.alas * self.tinggi
        print(f"Luas {self.nama}: {luas}")

def proses_bentuk(bentuk):
    print(f"\nMemproses objek: {type(bentuk)}")

    if isinstance(bentuk, BentukGeometri):
        bentuk.tampilkan_nama()
        print("Objek ini adalah instance dari BentukGeometri (atau turunannya)")
        if isinstance(bentuk, PersegiPanjang):
            print("-> Objek ini juga instance dari PersegiPanjang")
        elif isinstance(bentuk, Segitiga):
            print("-> Objek ini juga instance dari Segitiga")
    else:
        print("Objek ini bukan instance dari BentukGeometri")

    if isinstance(bentuk, str):
        print("Objek ini adalah string")

if __name__ == "__main__":
    pp = PersegiPanjang(4, 3)
    seg = Segitiga(5, 2)

    bg = BentukGeometri("Lingkaran")
    teks = "Ini string"

    daftar_obj = [pp, seg, bg, teks]

    for obj in daftar_obj:
        proses_bentuk(obj)
# Out:
# Memproses objek: <class '__main__.PersegiPanjang'>
# Ini adalah bentuk Persegi Panjang
# Objek ini adalah instance dari BentukGeometri (atau turunannya)
# -> Objek ini juga instance dari PersegiPanjang
#
# Memproses objek: <class '__main__.Segitiga'>
# Ini adalah bentuk Segitiga
# Objek ini adalah instance dari BentukGeometri (atau turunannya)
# -> Objek ini juga instance dari Segitiga
#
# Memproses objek: <class '__main__.BentukGeometri'>
# Ini adalah bentuk Lingkaran
# Objek ini adalah instance dari BentukGeometri (atau turunannya)
#
# Memproses objek: <class 'str'>
# Objek ini bukan instance dari BentukGeometri
# Objek ini adalah string

# %% [markdown]
# ## Penugasan - Program Hierarki Kelas Mahasiswa

# %%
class Mahasiswa:
    def __init__(self, nama, nim, ipk):
        self.nama = nama
        self.nim = nim
        self.ipk = ipk

    def tampilkan_info(self):
        print(f"Nama: {self.nama}")
        print(f"NIM: {self.nim}")
        print(f"IPK: {self.ipk}")

    def hitung_predikat(self):
        if self.ipk >= 3.5:
            return "Dengan Pujian"
        elif self.ipk >= 3.0:
            return "Sangat Memuaskan"
        elif self.ipk >= 2.5:
            return "Memuaskan"
        else:
            return "Cukup"

class MahasiswaSarjana(Mahasiswa):
    def __init__(self, nama, nim, ipk, semester, sks_lulus):
        super().__init__(nama, nim, ipk)
        self.semester = semester
        self.sks_lulus = sks_lulus

    def tampilkan_info(self):
        super().tampilkan_info()
        print(f"Semester: {self.semester}")
        print(f"SKS Lulus: {self.sks_lulus}")
        print(f"Predikat: {self.hitung_predikat()}")

class MahasiswaMagister(Mahasiswa):
    def __init__(self, nama, nim, ipk, judul_tesis, nama_pembimbing):
        super().__init__(nama, nim, ipk) 
        self.judul_tesis = judul_tesis
        self.nama_pembimbing = nama_pembimbing

    def tampilkan_info(self):
        super().tampilkan_info()
        print(f"Judul Tesis: {self.judul_tesis}")
        print(f"Pembimbing: {self.nama_pembimbing}")
        print(f"Predikat: {self.hitung_predikat()}")

if __name__ == "__main__":
    print("=== DATA MAHASISWA SARJANA ===")
    mhs_s1 = MahasiswaSarjana("Budi Santoso", "2023001", 3.6, 4, 80)
    mhs_s1.tampilkan_info()
    
    print("\n" + "="*30 + "\n")

    print("=== DATA MAHASISWA MAGISTER ===")
    mhs_s2 = MahasiswaMagister("Siti Aminah", "2023999", 3.85, "Optimasi AI pada Pertanian", "Dr. Ir. Prayitno")
    mhs_s2.tampilkan_info()
# Out:
# === DATA MAHASISWA SARJANA ===
# Nama: Budi Santoso
# NIM: 2023001
# IPK: 3.6
# Semester: 4
# SKS Lulus: 80
# Predikat: Dengan Pujian
#
# ==============================
#
# === DATA MAHASISWA MAGISTER ===
# Nama: Siti Aminah
# NIM: 2023999
# IPK: 3.85
# Judul Tesis: Optimasi AI pada Pertanian
# Pembimbing: Dr. Ir. Prayitno
# Predikat: Dengan Pujian
